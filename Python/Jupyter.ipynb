# %%
import os
os.listdir()

# %%
import pandas
df = pandas.read_csv('supermarkets.csv')
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
js = pandas.read_json('supermarkets.json')
js
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
excel = pandas.read_excel('example.xlsx')
excel
# Out:
#     2019-06-08 00:00:00 28/08/2019  13/09/2019  25/09/2019  19/12/2019  \
# 0              212208.0     211496    281118.0    279800.0    211368.0
# 1              211494.0      fhfhf    212177.0    236164.0    313349.0
# 2              266847.0     235759    212180.0    308424.0    318272.0
# 3              268471.0     210952    284097.0    268669.0    211370.0
# 4              284056.0     212232    283449.0    254886.0         NaN
# 5              268470.0     279796    268422.0    239931.0         NaN
# 6              284059.0     211141    268423.0    218873.0         NaN
# 7              284078.0     211148    226445.0    218989.0         NaN
# 8              216203.0     211185    268459.0    219052.0         NaN
# 9              216205.0     219426    235496.0    219074.0         NaN
# 10                  NaN     280977    216204.0    212209.0         NaN
# 11                  NaN     252477         NaN    212211.0         NaN
# ...
